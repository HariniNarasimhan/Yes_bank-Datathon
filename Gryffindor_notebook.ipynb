# %% [markdown]
# # Machine Learning Challenge - Round -1

# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from fastai.imports import *
from fastai.structured import *

from pandas_summary import DataFrameSummary
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from IPython.display import display

from sklearn import metrics

# %% [markdown]
# Path for the data

# %%
PATH = "data/yesbank/"

# %%
df_raw = pd.read_csv(f'{PATH}ml2_train.csv', low_memory=False, 
                     parse_dates=["Established_Date"],dayfirst = True)

df_test = pd.read_csv(f'{PATH}ml2_test.csv', low_memory=False,
                    parse_dates = ["Established_Date"],dayfirst = True)

# %% [markdown]
# it's important to look at your data, to make sure you understand the format, how it's stored, what type of values it holds, etc.

# %%
def display_all(df):
    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000):
        display(df)

# %%
display_all(df_raw.tail().T)
# Out:
#                                  3785                 3786  \
# Serial_Number                    3786                 3787
# Main_Office                         0                    0
# Branch_Number                    7981                 7982
# Established_Date  2015-03-11 00:00:00  2016-02-02 00:00:00
# Acquired_Date                     NaN                  NaN
# City                          Compton            Las Vegas
# County                    Los Angeles                Clark
# State                              CA                   NV
# Deposits_2010                     NaN                  NaN
# Deposits_2011                     NaN                  NaN
# Deposits_2012                     NaN                  NaN
# Deposits_2013                     NaN                  NaN
# Deposits_2014                     NaN                  NaN
# Deposits_2015                     NaN                  NaN
# Deposits_2016                    3446                 2666
#
#                                  3787                 3788  \
# Serial_Number                    3788                 3789
# Main_Office                         0                    0
# Branch_Number                    7984                 7988
# Established_Date  2016-03-15 00:00:00  2016-01-01 00:00:00
# Acquired_Date                     NaN                  NaN
# City                           Irvine          New Orleans
# County                         Orange              Orleans
# State                              CA                   LA
# Deposits_2010                     NaN                  NaN
# Deposits_2011                     NaN                  NaN
# Deposits_2012                     NaN                  NaN
# Deposits_2013                     NaN                  NaN
# Deposits_2014                     NaN                  NaN
# Deposits_2015                     NaN                  NaN
# Deposits_2016                    6689                94133
#
#                                  3789
# Serial_Number                    3790
# Main_Office                         0
# Branch_Number                    7989
# Established_Date  2016-01-01 00:00:00
# Acquired_Date                     NaN
# City                          Buffalo
# County                           Erie
# State                              NY
# Deposits_2010                     NaN
# Deposits_2011                     NaN
# Deposits_2012                     NaN
# Deposits_2013                     NaN
# Deposits_2014                     NaN
# Deposits_2015                     NaN
# Deposits_2016                   45596

# %%
display_all(df_raw.describe(include='all').T)
# Out:
#                  count unique                  top  freq                first  \
# Serial_Number     3790    NaN                  NaN   NaN                  NaN
# Main_Office       3790    NaN                  NaN   NaN                  NaN
# Branch_Number     3790    NaN                  NaN   NaN                  NaN
# Established_Date  3790   2027  1919-01-01 00:00:00   129  1825-01-01 00:00:00
# Acquired_Date     2297      5           09/25/2008  1528                  NaN
# City              3790   1489              Chicago    99                  NaN
# County            3790    299          Los Angeles   298                  NaN
# State             3790     25                   CA  1003                  NaN
# Deposits_2010     3050    NaN                  NaN   NaN                  NaN
# Deposits_2011     3212    NaN                  NaN   NaN                  NaN
# Deposits_2012     3461    NaN                  NaN   NaN                  NaN
# Deposits_2013     3615    NaN                  NaN   NaN                  NaN
# Deposits_2014     3734    NaN                  NaN   NaN                  NaN
# Deposits_2015     3771    NaN                  NaN   NaN                  NaN
# Deposits_2016     3790    NaN                  NaN   NaN                  NaN
#
#                                  last     mean          std   min      25%  \
# Serial_Number                     NaN   1895.5      1094.22     1   948.25
# Main_Office                       NaN        0            0     0        0
# Branch_Number                     NaN  5390.81      1549.11  2866  4062.25
# Established_Date  2016-10-05 00:00:00      NaN          NaN   NaN      NaN
# Acquired_Date                     NaN      NaN          NaN   NaN      NaN
# City                              NaN      NaN          NaN   NaN      NaN
# County                            NaN      NaN          NaN   NaN      NaN
# State                             NaN      NaN          NaN   NaN      NaN
# Deposits_2010                     NaN   112213  2.79759e+06     0    18932
# Deposits_2011                     NaN   125514  3.44738e+06     0  20132.8
# Deposits_2012                     NaN   128920  3.54715e+06     0    21065
# Deposits_2013                     NaN   136383  3.74036e+06     0  23314.5
# Deposits_2014                     NaN   145592  3.98028e+06     0    26239
# Deposits_2015                     NaN   157628  4.28141e+06     0    30881
# Deposits_2016                     NaN   183256  5.11612e+06     0  37091.5
#
#                      50%      75%          max
# Serial_Number     1895.5  2842.75         3790
# Main_Office            0        0            0
# Branch_Number     5256.5  6858.25         7989
# Established_Date     NaN      NaN          NaN
# Acquired_Date        NaN      NaN          NaN
# City                 NaN      NaN          NaN
# County               NaN      NaN          NaN
# State                NaN      NaN          NaN
# Deposits_2010      35628  66072.8  1.53577e+08
# Deposits_2011      37183    66947  1.94388e+08
# Deposits_2012      39744    71496  2.07368e+08
# Deposits_2013      42358  76352.5  2.23395e+08
# Deposits_2014      46772  83296.5  2.41541e+08
# Deposits_2015      52516    91566  2.61293e+08
# Deposits_2016      60753   104378  3.13687e+08

# %% [markdown]
# # Initial Processing

# %% [markdown]
# This dataset contains a mix of continuous and categorical variables.
# The below method extracts particular date fields from a complete datetime for the purpose of constructing categoricals.

# %%
add_datepart(df_raw,'Established_Date')
df_raw.Established_Year.head()
add_datepart(df_test,'Established_Date')

# %% [markdown]
# we call the function train_cats to convert strings to pandas categories.

# %%
train_cats(df_raw)
train_cats(df_test)

# %% [markdown]
# The below step is to replace the text to numericals

# %%
df_raw.City.cat.categories
df_raw.County.cat.categories
df_raw.State.cat.categories
df_test.City.cat.categories
df_test.County.cat.categories
df_test.State.cat.categories
# Out:
# Index(['AZ', 'CT', 'FL', 'IL', 'KY', 'LA', 'MI', 'NJ', 'NY', 'OH', 'TX', 'UT',
#        'WI', 'WV'],
#       dtype='object')

# %% [markdown]
# output : Index(['AZ', 'CT', 'FL', 'IL', 'KY', 'LA', 'MI', 'NJ', 'NY', 'OH', 'TX', 'UT',
#        'WI', 'WV'],
#       dtype='object')

# %%
df_raw.City = df_raw.City.cat.codes
df_raw.County = df_raw.County.cat.codes
df_raw.State = df_raw.State.cat.codes
df_test.City = df_test.City.cat.codes
df_test.County = df_test.County.cat.codes
df_test.State = df_test.State.cat.codes

# %% [markdown]
# Since we have lots of missing values, which we can't pass directly to a random forest.

# %%
display_all(df_raw.isnull().sum().sort_index()/len(df_raw))
display_all(df_test.isnull().sum().sort_index()/len(df_test))
# Out:
# Acquired_Date                   0.393931
# Branch_Number                   0.000000
# City                            0.000000
# County                          0.000000
# Deposits_2010                   0.195251
# Deposits_2011                   0.152507
# Deposits_2012                   0.086807
# Deposits_2013                   0.046174
# Deposits_2014                   0.014776
# Deposits_2015                   0.005013
# Deposits_2016                   0.000000
# Established_Day                 0.000000
# Established_Dayofweek           0.000000
# Established_Dayofyear           0.000000
# Established_Elapsed             0.000000
# Established_Is_month_end        0.000000
# Established_Is_month_start      0.000000
# Established_Is_quarter_end      0.000000
# Established_Is_quarter_start    0.000000
# Established_Is_year_end         0.000000
# Established_Is_year_start       0.000000
# Established_Month               0.000000
# Established_Week                0.000000
# Established_Year                0.000000
# Main_Office                     0.000000
# Serial_Number                   0.000000
# State                           0.000000
# dtype: float64
# Acquired_Date                   0.075169
# Branch_Number                   0.000000
# City                            0.000000
# County                          0.000000
# Deposits_2010                   0.000000
# Deposits_2011                   0.000000
# Deposits_2012                   0.000000
# Deposits_2013                   0.000000
# Deposits_2014                   0.000000
# Deposits_2015                   0.000000
# Established_Day                 0.000000
# Established_Dayofweek           0.000000
# Established_Dayofyear           0.000000
# Established_Elapsed             0.000000
# Established_Is_month_end        0.000000
# Established_Is_month_start      0.000000
# Established_Is_quarter_end      0.000000
# Established_Is_quarter_start    0.000000
# Established_Is_year_end         0.000000
# Established_Is_year_start       0.000000
# Established_Month               0.000000
# Established_Week                0.000000
# Established_Year                0.000000
# Main_Office                     0.000000
# Serial_Number                   0.000000
# State                           0.000000
# dtype: float64

# %% [markdown]
# # Preprocessing

# %% [markdown]
# Since we have lots of training data compared to test data available, the training data has been splitted to required number in order to overcome overfitting.

# %%
def split_vals(a,n): return a[:n].copy(), a[n:].copy()

n_valid = 2167  # same as Kaggle's test set size
n_trn = len(df_raw)-n_valid
raw_train, raw_valid = split_vals(df_raw, n_trn)
raw_train.shape
df_raw = raw_train

# %% [markdown]
# We'll replace categories with their numeric codes, handle missing continuous values, and split the dependent variable into a separate variable.

# %%
df, y, nas = proc_df(df_raw, 'Deposits_2016')
df1, y1, nas1 = proc_df(df_test)
df
# Out:
#       Serial_Number  Main_Office  Branch_Number  Acquired_Date  City  County  \
# 0                 1            0           2866              5  1383     279
# 1                 2            0           2867              5   451     277
# 2                 3            0           2868              5   137     279
# 3                 4            0           2869              5  1005     279
# 4                 5            0           2870              5  1401     279
# 5                 6            0           2871              5  1401     279
# 6                 7            0           2872              5   137     279
# 7                 8            0           2873              5   859     279
# 8                 9            0           2874              5   936     279
# 9                10            0           2875              5   159     279
# 10               11            0           2876              5   845     279
# 11               12            0           2877              5  1401     279
# 22       24        36034.0        39054.0        47172.0        ...
# 23       24        41540.0        45722.0        49287.0        ...
# 24       24        63075.0        69062.0        79939.0        ...
# 25       24        43225.0        51113.0        51254.0        ...
# 26       24       151797.0        99047.0       109104.0        ...
# 27       24        54152.0        42828.0        43477.0        ...
# 28       24       223146.0       253314.0       281540.0        ...
# 29       24        26675.0        27337.0        27643.0        ...
# ...     ...            ...            ...            ...        ...
# 3760      5        35628.0        37183.0        39744.0        ...
# 3761      1        35628.0        37183.0        39744.0        ...
# 3762      5        35628.0        37183.0        39744.0        ...
# 3763      5        35628.0        37183.0        39744.0        ...
# 3764      8        35628.0        37183.0        39744.0        ...
# 3765     16        35628.0        37183.0        39744.0        ...
# 3766      5        35628.0        37183.0        39744.0        ...
# 3767      1        35628.0        37183.0        39744.0        ...
# 3768      5        35628.0        37183.0        39744.0        ...
# 3769      3        35628.0        37183.0        39744.0        ...
# 3770      5        35628.0        37183.0        39744.0        ...
# 3771      5        35628.0        37183.0        39744.0        ...
# 3772      1        35628.0        37183.0        39744.0        ...
# 3773     14        35628.0        37183.0        39744.0        ...
# 3774      5        35628.0        37183.0        39744.0        ...
# 3775      5        35628.0        37183.0        39744.0        ...
# 3776      2        35628.0        37183.0        39744.0        ...
# 3777      8        35628.0        37183.0        39744.0        ...
# 3778      5        35628.0        37183.0        39744.0        ...
# 3779      1        35628.0        37183.0        39744.0        ...
# 3780      1        35628.0        37183.0        39744.0        ...
# 3781     18        35628.0        37183.0        39744.0        ...
# 3782      5        35628.0        37183.0        39744.0        ...
# 3783      5        35628.0        37183.0        39744.0        ...
# 3784      1        35628.0        37183.0        39744.0        ...
# 3785      1        35628.0        37183.0        39744.0        ...
# 3786     15        35628.0        37183.0        39744.0        ...
# 3787      1        35628.0        37183.0        39744.0        ...
# 3788     11        35628.0        37183.0        39744.0        ...
# 3789     16        35628.0        37183.0        39744.0        ...
#
#       Established_Is_quarter_start  Established_Is_year_end  \
# 0                            False                    False
# 1                            False                    False
# 2                            False                    False
# 3                            False                    False
# 4                            False                    False
# 5                            False                    False
# 6                            False                    False
# 7                             True                    False
# 8                            False                    False
# 9                            False                    False
# 10                           False                    False
# 11                           False                    False
# 12                           False                    False
# 13                           False                    False
# 14                           False                    False
# 15                            True                    False
# 16                            True                    False
# 17                           False                    False
# 18                           False                    False
# 19                            True                    False
# 20                           False                    False
# 21                           False                    False
# 22                           False                    False
# 23                           False                    False
# 24                           False                    False
# 25                           False                    False
# 26                           False                    False
# 27                           False                    False
# 28                           False                    False
# 29                            True                    False
# ...                            ...                      ...
# 3760                         False                    False
# 3761                         False                    False
# 3762                         False                    False
# 3763                         False                    False
# 3764                         False                    False
# 3765                         False                    False
# 3766                         False                    False
# 3767                         False                    False
# 3768                         False                    False
# 3769                         False                    False
# 3770                         False                    False
# 3771                         False                    False
# 3772                         False                    False
# 3773                         False                    False
# 3774                         False                    False
# 3775                         False                    False
# 3776                         False                    False
# 3777                         False                    False
# 3760              True              True              True              True
# 3761              True              True              True              True
# 3762              True              True              True              True
# 3763              True              True              True              True
# 3764              True              True              True              True
# 3765              True              True              True              True
# 3766              True              True              True              True
# 3767              True              True              True              True
# 3768              True              True              True              True
# 3769              True              True              True              True
# 3770              True              True              True              True
# 3771              True              True              True              True
# 3772              True              True              True              True
# 3773              True              True              True              True
# 3774              True              True              True              True
# 3775              True              True              True              True
# 3776              True              True              True              True
# 3777              True              True              True              True
# 3778              True              True              True              True
# 3779              True              True              True              True
# 3780              True              True              True              True
# 3781              True              True              True              True
# 3782              True              True              True              True
# 3783              True              True              True              True
# 3784              True              True              True              True
# 3785              True              True              True              True
# 3786              True              True              True              True
# 3787              True              True              True              True
# 3788              True              True              True              True
# 3789              True              True              True              True
#
#       Deposits_2015_na
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# 5                False
# 6                False
# 7                False
# 8                False
# 9                False
# 10               False
# 11               False
# 12               False
# 13               False
# 14               False
# 15               False
# 16               False
# 17               False
# 18               False
# 19               False
# 20               False
# 21               False
# 22               False
# 23               False
# 24               False
# 25               False
# 26               False
# 27               False
# 28               False
# 29               False
# ...                ...
# 3760             False
# 3761              True
# 3762             False
# 3763             False
# 3764             False
# 3765             False
# 3766             False
# 3767             False
# 3768             False
# 3769             False
# 3770             False
# 3771             False
# 3772              True
# 3773              True
# 3774              True
# 3775              True
# 3776              True
# 3777              True
# 3778              True
# 3779              True
# 3780              True
# 3781              True
# 3782              True
# 3783              True
# 3784              True
# 3785              True
# 3786              True
# 3787              True
# 3788              True
# 3789              True
#
# [3790 rows x 32 columns]

# %% [markdown]
# Now, the data is ready to fit the model using random forest regressor

# %%
m = RandomForestRegressor(n_jobs=-1)
m.fit(df, y)
m.score(df,y)
# Out:
# /home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.9206251464882599

# %% [markdown]
# Output: 0.9206251464882599
#
# The output is the coefficient of R^2
#
# This shows that the train data given is efficient for the prediction process of the test data.

# %% [markdown]
# ## Prediction of Test data

# %%
deposit = m.predict(df1)
deposit
# Out:
# array([1.65417e+08, 3.58472e+05, 2.86499e+05, ..., 1.06214e+05, 8.45572e+04, 2.75120e+04])

# %% [markdown]
# ## Clustering

# %%
A=[];
B=[];
C=[];
S1=[];
S2=[];
S3=[];
clu_a =[];
for i in range(len(deposit)):
    if (deposit[i]>=20000 and deposit[i]<=90000):
        A.append(deposit[i])
        S1.append(i+1)
    if (deposit[i] < 20000):
        B.append(deposit[i])
        S2.append(i+1)
    if (deposit[i] >90000):
        C.append(deposit[i])
        S3.append(i+1)    
deposit = A + B + C
Serialnum = S1 + S2 + S3

# %% [markdown]
# ## Creation of csv file

# %%
import csv

with open('submissionlast.csv','w',newline = '') as f:
    thewriter = csv.writer(f)
    thewriter.writerow(['Serial Number','2016 Deposits'])
    for i in range(len(deposit)):
        thewriter.writerow([Serialnum[i],deposit[i]])
